# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **TASK 1 : SPARK FOUNDATION D&MA INTERNSHIP**
#
#
# ---
#
#
#
# ---
#
#
# ## **Prediction using Supervised ML : simple linear regression**
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # **IMPORTING DATA SET**

# %%
# Importing all libraries required to predict using Given Data set 
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
#Import the data
url="http://bit.ly/w-data"
data=pd.read_csv(url)
data1=data
print("The data is imported successfully")
data
# Out:
# The data is imported successfully
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
# visualisation of Head and tail of Data
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# ---
#
#
# ## **DATA VISUALISATION**
#
#
# ---

# %%
# Plotting the distribution of scores
data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# By Analyzing Above Scatter plot Graph We Can see That Percentage Score and hours Studied are having Positive Linear Relationship.
#
#
# This means As long you study higher the score will be presented

# %% [markdown]
# ---
#
#
#
# # **PREPARATION OF DATA**
#
#
#
#
# ---

# %%
#Splitting training and testing data
x=data.iloc[:,:-1].values
y=data.iloc[:,1].values



x_train, x_test, y_train, y_test= train_test_split(x, y,train_size=0.80,test_size=0.20,random_state=0)

# %% [markdown]
# ---
#
#
#
# # **TRAINING THE MODEL CREATED FROM DATA SET**
#
#
#
#
# ---

# %%
from sklearn.linear_model import LinearRegression
linearRegressor= LinearRegression()
linearRegressor.fit(x_train, y_train)
y_predict= linearRegressor.predict(x_train)

# %% [markdown]
# ---
#
#
#
# # **TRAINING THE ALOGIRTHM FROM DATA SET**
#
#
#
#
# ---

# %%
regressor = LinearRegression()  
regressor.fit(x_train, y_train) 

print("Training complete.")
# Out:
# Training complete.

# %%
# Plotting the regression line
line = regressor.coef_*x+regressor.intercept_
# Plotting for the test data
plt.scatter(x, y)
plt.plot(x, line,color="red");
plt.show()

# %%
##importing libraries for plotting Graphs
import seaborn as sns

plt.boxplot(data)
plt.xlabel('X',fontsize=15)
plt.ylabel('Y',fontsize=15)
plt.title('Training Data Set plot', fontsize=10)

plt.show()

# %%
# Checking the accuracy scores for training and test set

print('Test Score')
print(regressor.score(x_test, y_test))
print('Training Score')
print(regressor.score(x_train, y_train))
# Out:
# Test Score
# 0.9454906892105354
# Training Score
# 0.9515510725211553

# %% [markdown]
# ---
#
#
# ## **PREDICTION OF DATA : Comparing Actual vs Predicted Scores**
#
#
# ---

# %%
print(x_test)
 # Testing data - In Hours
y_pred = regressor.predict(x_test) 
# Predicting the scores
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
#Let's predict the score for 9.25 hpurs
print('Score of student who studied for 9.25 hours a dat', regressor.predict([[9.25]]))
# Out:
# Score of student who studied for 9.25 hours a dat [93.69173249]

# %%
# ACCURACY OF THE MODEL

from sklearn import metrics
metrics.r2_score(y_test,y_pred)

##Goodness of fit Test
# Out:
# 0.9454906892105354

# %% [markdown]
#  Above 94% percentage indicates that above fitted Model is a GOOD MODEL for our valuation of Data set

# %% [markdown]
# ---
#
#
# # **ERROR PREDICTION AND MODEL EVALUATION**
#
# ---

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
MSE = metrics.mean_squared_error(y_test,y_pred)
root_E = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
Abs_E = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
print("Mean Squared Error      = ",MSE)
print("Root Mean Squared Error = ",root_E)
print("Mean Absolute Error     = ",Abs_E)
# Out:
# Mean Squared Error      =  21.598769307217456
# Root Mean Squared Error =  4.647447612100373
# Mean Absolute Error     =  4.647447612100373

# %% [markdown]
# ---
#
#
# # **CONCLUSIONS**
#
# ---
#
#
# From the above result after applying ML alogirthms on linear Regression model
#  we can say that if a student studies for 9.25 hours then student will secured 93.69 Marks with 94 % of Accuracy and Confidence interval

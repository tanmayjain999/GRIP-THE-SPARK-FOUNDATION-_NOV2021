# %% [markdown]
# ##Task 4: Exploratory Data Analysis on dataset 'Global Terrorism'
# Objective
#
# Perform 'Exploratory Data Analysis' on dataset "Global Terrorism".
#
# As a security / defense analyst, try to find out the hot zone terrorism.
#
# What all security issues and insights you can derive by EDA?
#
# ##Data Science Business Analytics Internship
# GRIP - The Sparks Foundaton

# %% [markdown]
# ###**Reading** The Data and Visualisation of the Data

# %%
# Read data
import numpy as np                           
import pandas as pd

# %%
# Visualization
# Visualization
import matplotlib.pyplot as plt              # Visualization using matplotlib
# %matplotlib inline
import seaborn as sns                        # Visualization using seaborn

# style
plt.style.use("fivethirtyeight")             # Set Graphs Background style using matplotlib
sns.set_style("darkgrid")                    # Set Graphs Background style using seaborn

import warnings                              # To ignore any warnings
warnings.filterwarnings("ignore")

# %%
# for interactivity
from ipywidgets import interact

# %%
# Loading the dataset
df = pd.read_csv("globalterrorismdb_0718dist.csv", low_memory=False, encoding='latin-1')
pd.set_option('max_columns', 135)

# %%
# Loading the dataset
df = pd.read_csv("globalterrorismdb_0718dist.csv", low_memory=False, encoding='latin-1')
pd.set_option('max_columns', 135)

# %%
# import first & last 5 rows
display(df.head())
display(df.tail())
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164            1         0      NaN
# 1    Mexico city  19.371887  -99.086624            1         0      NaN
# 2        Unknown  15.478598  120.599741            4         0      NaN
# 3         Athens  37.997490   23.762728            1         0      NaN
# 4        Fukouka  33.580412  130.396361            1         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1          0          NaN             NaN
# 1     NaN      1      1      1          0          NaN             NaN
# 2     NaN      1      1      1          0          NaN             NaN
# 3     NaN      1      1      1          0          NaN             NaN
# 4     NaN      1      1      1         -9          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0         0        1        0            1                   Assassination
# 1         0        1        0            6     Hostage Taking (Kidnapping)
# 2         0        1        0            1                   Assassination
# 3         0        1        0            3               Bombing/Explosion
# 4         0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2  gsubname2  gname3  \
# 0                              MANO-D      NaN    NaN        NaN     NaN
# 1  23rd of September Communist League      NaN    NaN        NaN     NaN
# 2                             Unknown      NaN    NaN        NaN     NaN
# 3                             Unknown      NaN    NaN        NaN     NaN
# 4                             Unknown      NaN    NaN        NaN     NaN
#
#    gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  \
# 0        NaN    NaN          0.0          NaN          NaN         0.0
# 1        NaN    NaN          0.0          NaN          NaN         0.0
# 2        NaN    NaN          0.0          NaN          NaN         0.0
# 3        NaN    NaN          0.0          NaN          NaN         0.0
# 4        NaN    NaN          0.0          NaN          NaN         0.0
#
#    nperps  nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 1     7.0       NaN      NaN        NaN           NaN     NaN         NaN
# 2     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 3     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 4     NaN       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3  claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN             NaN        NaN       13.0
# 1            NaN     NaN         NaN             NaN        NaN       13.0
# 2            NaN     NaN         NaN             NaN        NaN       13.0
# 3            NaN     NaN         NaN             NaN        NaN        6.0
# 4            NaN     NaN         NaN             NaN        NaN        8.0
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN       0.0         NaN            NaN        NaN         NaN
# 1       NaN       0.0         NaN            NaN        NaN         NaN
# 2       NaN       0.0         NaN            NaN        NaN         NaN
# 3       NaN       1.0         NaN            NaN        NaN         NaN
# 4       NaN       1.0         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS      0.0       0.0       0.0      0.0     NaN
# 1     PGIS      0.0       1.0       1.0      1.0     NaN
# 2     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 3     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 4     PGIS     -9.0      -9.0       1.0      1.0     NaN
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 7311  197901090003   1979       1     9        NaN         0        NaN
# 7312  197901090004   1979       1     9        NaN         0        NaN
# 7313  197901090007   1979       1     9        NaN         0        NaN
# 7314  197901100001   1979       1    10        NaN         0        NaN
# 7315  197901100002   1979       1    10        NaN         0        NaN
#
#       country     country_txt  region      region_txt         provstate  \
# 7311      138         Myanmar       5  Southeast Asia              Shan
# 7312       98           Italy       8  Western Europe             Lazio
# 7313      603  United Kingdom       8  Western Europe  Northern Ireland
# 7314       98           Italy       8  Western Europe             Lazio
# 7315       98           Italy       8  Western Europe             Lazio
#
#            city   latitude  longitude  specificity  vicinity location summary  \
# 7311  Mong Tong  20.292237  98.895448            1         0      NaN     NaN
# 7312       Rome  41.890961  12.490069            1         0      NaN     NaN
# 7313    Belfast  54.607712  -5.956210            1         0      NaN     NaN
# 7314       Rome  41.890961  12.490069            1         0      NaN     NaN
# 7315       Rome  41.890961  12.490069            1         0      NaN     NaN
#
#       crit1  crit2  crit3  doubtterr  alternative             alternative_txt  \
# 7311      1      1      0          1          1.0  Insurgency/Guerilla Action
# 7312      1      1      1          0          NaN                         NaN
# 7313      1      1      1          0          NaN                         NaN
# 7314      1      1      1          0          NaN                         NaN
# 7315      1      1      1          0          NaN                         NaN
#
#       multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 7311         0        1        0            2                   Armed Assault
# 7312         0        1        0            6     Hostage Taking (Kidnapping)
# 7313         0        1        0            2                   Armed Assault
# 7314         0        1        0            7  Facility/Infrastructure Attack
# 7315         0        1        0            1                   Assassination
#
#       attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 7311          NaN             NaN          NaN             NaN          4
# 7312          NaN             NaN          NaN             NaN         10
# 7313          NaN             NaN          NaN             NaN          3
# 7314          NaN             NaN          NaN             NaN          2
# 7315          NaN             NaN          NaN             NaN         22
#
#                 targtype1_txt  targsubtype1  \
# 7311                 Military          29.0
# 7312      Journalists & Media          54.0
# 7313                   Police          23.0
# 7314     Government (General)          15.0
# 7315  Violent Political Party         109.0
#
#                                        targsubtype1_txt  \
# 7311                        Military Unit/Patrol/Convoy
# 7312                    Radio Journalist/Staff/Facility
# 7313     Police Patrol (including vehicles and convoys)
# 7314  Politician or Political Party Movement/Meeting...
# 7315           Party Official/Candidate/Other Personnel
#
#                            corp1                           target1  natlty1  \
# 7311                         NaN         1st Kayah Rifles regiment    138.0
# 7312                         NaN  Radio Future City (Citia Futura)     98.0
# 7313                         NaN                     police patrol    216.0
# 7314                         NaN           Christian Demo Party HQ     98.0
# 7315  Italian Social Movement (M                               NaN      NaN
#
#         natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 7311        Myanmar        NaN           NaN           NaN              NaN
# 7312          Italy        NaN           NaN           NaN              NaN
# 7313  Great Britain        NaN           NaN           NaN              NaN
# 7314          Italy        NaN           NaN           NaN              NaN
# 7315            NaN        NaN           NaN           NaN              NaN
#
#      corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  \
# 7311   NaN     NaN      NaN         NaN        NaN           NaN
# 7312   NaN     NaN      NaN         NaN        NaN           NaN
# 7313   NaN     NaN      NaN         NaN        NaN           NaN
# 7314   NaN     NaN      NaN         NaN        NaN           NaN
# 7315   NaN     NaN      NaN         NaN        NaN           NaN
#
#       targsubtype3 targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 7311           NaN              NaN   NaN     NaN      NaN         NaN
# 7312           NaN              NaN   NaN     NaN      NaN         NaN
# 7313           NaN              NaN   NaN     NaN      NaN         NaN
# 7314           NaN              NaN   NaN     NaN      NaN         NaN
# 7315           NaN              NaN   NaN     NaN      NaN         NaN
#
#                                  gname gsubname gname2  gsubname2  gname3  \
# 7311           People's Army (Myanmar)      NaN    NaN        NaN     NaN
# 7312  Armed Revolutionary Nuclei (NAR)      NaN    NaN        NaN     NaN
# 7313       Irish Republican Army (IRA)      NaN    NaN        NaN     NaN
# 7314     Italian Social Movement (MSI)      NaN    NaN        NaN     NaN
# 7315                               NaN      NaN    NaN        NaN     NaN
#
#       gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  \
# 7311        NaN    NaN          0.0          NaN          NaN         0.0
# 7312        NaN    NaN          0.0          NaN          NaN         0.0
# 7313        NaN    NaN          0.0          NaN          NaN         0.0
# 7314        NaN    NaN          0.0          NaN          NaN         0.0
# 7315        NaN    NaN          NaN          NaN          NaN         NaN
#
#       nperps  nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 7311     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 7312     4.0       NaN      NaN        NaN           NaN     NaN         NaN
# 7313     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 7314     1.0       NaN      NaN        NaN           NaN     NaN         NaN
# 7315     NaN       NaN      NaN        NaN           NaN     NaN         NaN
#
#      claimmode2_txt  claim3  claimmode3  claimmode3_txt  compclaim  weaptype1  \
# 7311            NaN     NaN         NaN             NaN        NaN        5.0
# 7312            NaN     NaN         NaN             NaN        NaN        5.0
# 7313            NaN     NaN         NaN             NaN        NaN        5.0
# 7314            NaN     NaN         NaN             NaN        NaN        8.0
# 7315            NaN     NaN         NaN             NaN        NaN        NaN
#
#      weaptype1_txt  weapsubtype1                   weapsubtype1_txt  \
# 7311      Firearms           2.0  Automatic or Semi-Automatic Rifle
# 7312      Firearms           2.0  Automatic or Semi-Automatic Rifle
# 7313      Firearms           4.0      Rifle/Shotgun (non-automatic)
# 7314    Incendiary           NaN                                NaN
# 7315           NaN           NaN                                NaN
#
#       weaptype2 weaptype2_txt  weapsubtype2        weapsubtype2_txt  \
# 7311        NaN           NaN           NaN                     NaN
# 7312        6.0    Explosives          16.0  Unknown Explosive Type
# 7313        NaN           NaN           NaN                     NaN
# 7314        NaN           NaN           NaN                     NaN
# 7315        NaN           NaN           NaN                     NaN
#
#       weaptype3 weaptype3_txt  weapsubtype3 weapsubtype3_txt  weaptype4  \
# 7311        NaN           NaN           NaN              NaN        NaN
# 7312        NaN           NaN           NaN              NaN        NaN
# 7313        NaN           NaN           NaN              NaN        NaN
# 7314        NaN           NaN           NaN              NaN        NaN
# 7315        NaN           NaN           NaN              NaN        NaN
#
#      weaptype4_txt  weapsubtype4 weapsubtype4_txt  \
# 7311           NaN           NaN              NaN
# 7312           NaN           NaN              NaN
# 7313           NaN           NaN              NaN
# 7314           NaN           NaN              NaN
# 7315           NaN           NaN              NaN
#
#                          weapdetail  nkill  nkillus  nkillter  nwound  \
# 7311              Automatic firearm    8.0      NaN       NaN     4.0
# 7312  Automatic firearm; Explosives    0.0      NaN       NaN     5.0
# 7313                          Rifle    0.0      NaN       NaN     1.0
# 7314                     Incendiary    1.0      NaN       NaN     0.0
# 7315                            NaN    NaN      NaN       NaN     NaN
#
#       nwoundus  nwoundte  property  propextent               propextent_txt  \
# 7311       NaN       NaN       1.0         4.0                      Unknown
# 7312       NaN       NaN       1.0         3.0  Minor (likely < $1 million)
# 7313       NaN       NaN       1.0         4.0                      Unknown
# 7314       NaN       NaN       1.0         4.0                      Unknown
# 7315       NaN       NaN       NaN         NaN                          NaN
#
#       propvalue propcomment  ishostkid  nhostkid  nhostkidus  nhours  ndays  \
# 7311        NaN         NaN        0.0       NaN         NaN     NaN    NaN
# 7312    35000.0         NaN        1.0       4.0         0.0     NaN    NaN
# 7313        NaN         NaN        0.0       NaN         NaN     NaN    NaN
# 7314        NaN         NaN        0.0       NaN         NaN     NaN    NaN
# 7315        NaN         NaN        NaN       NaN         NaN     NaN    NaN
#
#      divert kidhijcountry  ransom  ransomamt  ransomamtus  ransompaid  \
# 7311    NaN           NaN     0.0        NaN          NaN         NaN
# 7312    NaN           NaN     0.0        NaN          NaN         NaN
# 7313    NaN           NaN     0.0        NaN          NaN         NaN
# 7314    NaN           NaN     0.0        NaN          NaN         NaN
# 7315    NaN           NaN     NaN        NaN          NaN         NaN
#
#       ransompaidus ransomnote  hostkidoutcome hostkidoutcome_txt  nreleased  \
# 7311           NaN        NaN             NaN                NaN        NaN
# 7312           NaN        NaN             NaN                NaN        NaN
# 7313           NaN        NaN             NaN                NaN        NaN
# 7314           NaN        NaN             NaN                NaN        NaN
# 7315           NaN        NaN             NaN                NaN        NaN
#
#      addnotes scite1 scite2 scite3 dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 7311      NaN    NaN    NaN    NaN     PGIS      0.0       0.0       0.0
# 7312      NaN    NaN    NaN    NaN     PGIS      0.0       0.0       0.0
# 7313      NaN    NaN    NaN    NaN     PGIS      0.0       0.0       1.0
# 7314      NaN    NaN    NaN    NaN     PGIS      0.0       0.0       0.0
# 7315      NaN    NaN    NaN    NaN      NaN      NaN       NaN       NaN
#
#       INT_ANY related
# 7311      0.0     NaN
# 7312      0.0     NaN
# 7313      1.0     NaN
# 7314      0.0     NaN
# 7315      NaN     NaN

# %% [markdown]
# ###duplicate and null values are checked by transforming the data

# %%
# Checking for any duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.658100e+04  16581.000000  16581.000000  16581.000000  16581.000000
# mean   1.978029e+11   1977.966045      6.201978     15.155962      0.020445
# std    3.266916e+08      3.270107      3.415697      8.949768      0.141521
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.976092e+11   1976.000000      3.000000      7.000000      0.000000
# 50%    1.979051e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.980121e+11   1980.000000      9.000000     23.000000      0.000000
# max    1.982072e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  16581.000000  16581.000000  15975.000000  15975.000000  16581.000000
# mean     183.120258      5.524878     27.875821    -28.932087      1.253543
# std      170.441089      3.372000     22.109249     55.936993      0.905089
# min        4.000000      1.000000    -45.867889   -157.818968      1.000000
# 25%       69.000000      2.000000     13.692880    -86.600964      1.000000
# 50%      110.000000      8.000000     35.689125     -6.443767      1.000000
# 75%      217.000000      8.000000     43.291618      9.991586      1.000000
# max      605.000000     12.000000     64.837778    172.636225      5.000000
#
#            vicinity         crit1         crit2         crit3     doubtterr  \
# count  16581.000000  16581.000000  16581.000000  16581.000000  16581.000000
# mean       0.010494      0.988481      0.990531      0.890477     -1.554912
# std        0.101904      0.106711      0.096848      0.312304      3.600439
# min        0.000000      0.000000      0.000000      0.000000     -9.000000
# 25%        0.000000      1.000000      1.000000      1.000000      0.000000
# 50%        0.000000      1.000000      1.000000      1.000000      0.000000
# 75%        0.000000      1.000000      1.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        alternative      multiple       success       suicide   attacktype1  \
# count  2299.000000  16581.000000  16581.000000  16581.000000  16581.000000
# mean      1.269682      0.042579      0.907665      0.000060      3.166757
# std       0.560056      0.201912      0.289506      0.007766      2.010886
# min       1.000000      0.000000      0.000000      0.000000      1.000000
# 25%       1.000000      0.000000      1.000000      0.000000      2.000000
# 50%       1.000000      0.000000      1.000000      0.000000      3.000000
# 75%       1.000000      0.000000      1.000000      0.000000      3.000000
# max       3.000000      1.000000      1.000000      1.000000      9.000000
#
#        attacktype2  attacktype3     targtype1  targsubtype1       natlty1  \
# count    26.000000     2.000000  16581.000000  15612.000000  16530.000000
# mean      4.884615     3.000000      6.913938     40.849154    140.546038
# std       2.454823     1.414214      6.249739     30.686157     79.496539
# min       2.000000     2.000000      1.000000      1.000000      4.000000
# 25%       2.000000     2.500000      2.000000     15.000000     69.000000
# 50%       7.000000     3.000000      4.000000     29.000000    130.000000
# 75%       7.000000     3.500000     14.000000     69.000000    216.000000
# max       7.000000     4.000000     22.000000    113.000000    999.000000
#
#         targtype2  targsubtype2     natlty2  targtype3  targsubtype3  \
# count  218.000000    157.000000  189.000000  27.000000     17.000000
# mean     9.389908     50.159236  169.031746   8.444444     53.176471
# std      6.835748     28.284160   83.474860   5.866026     24.963061
# min      1.000000      1.000000   11.000000   1.000000      8.000000
# 25%      3.000000     25.000000   94.000000   3.000000     34.000000
# 50%      8.000000     53.000000  216.000000   7.000000     53.000000
# 75%     14.000000     69.000000  217.000000  14.000000     77.000000
# max     22.000000    108.000000  605.000000  22.000000     85.000000
#
#           natlty3  gsubname2  gname3  gsubname3   guncertain1  guncertain2  \
# count   27.000000        0.0     0.0        0.0  16580.000000    35.000000
# mean   138.074074        NaN     NaN        NaN      0.041737     0.342857
# std     70.642614        NaN     NaN        NaN      0.199994     0.481594
# min     32.000000        NaN     NaN        NaN      0.000000     0.000000
# 25%     83.000000        NaN     NaN        NaN      0.000000     0.000000
# 50%    110.000000        NaN     NaN        NaN      0.000000     0.000000
# 75%    216.000000        NaN     NaN        NaN      0.000000     1.000000
# max    233.000000        NaN     NaN        NaN      1.000000     1.000000
#
#        guncertain3    individual       nperps    nperpcap     claimed  \
# count          0.0  16580.000000  3384.000000  934.000000  939.000000
# mean           NaN      0.002413   -11.666076  -80.271949   -0.082002
# std            NaN      0.049060    57.411538   39.316957    1.808145
# min            NaN      0.000000   -99.000000  -99.000000   -9.000000
# 25%            NaN      0.000000     1.000000  -99.000000    0.000000
# 50%            NaN      0.000000     2.000000  -99.000000    0.000000
# 75%            NaN      0.000000     5.000000  -99.000000    1.000000
# max            NaN      1.000000  1000.000000   26.000000    1.000000
#
#         claimmode    claim2  claimmode2  claim3  claimmode3  claimmode3_txt  \
# count  238.000000  9.000000    8.000000     0.0         0.0             0.0
# mean     4.399160  0.888889    2.750000     NaN         NaN             NaN
# std      3.001462  0.333333    2.964071     NaN         NaN             NaN
# min      1.000000  0.000000    1.000000     NaN         NaN             NaN
# 25%      2.000000  1.000000    1.750000     NaN         NaN             NaN
# 50%      5.000000  1.000000    2.000000     NaN         NaN             NaN
# 75%      5.000000  1.000000    2.000000     NaN         NaN             NaN
# max     10.000000  1.000000   10.000000     NaN         NaN             NaN
#
#        compclaim     weaptype1  weapsubtype1    weaptype2  weapsubtype2  \
# count  18.000000  16580.000000  13343.000000  1038.000000    878.000000
# mean    0.444444      6.639867     10.637113     6.364162      9.586560
# std     0.511310      2.404941      7.099814     1.888489      6.900079
# min     0.000000      1.000000      1.000000     2.000000      2.000000
# 25%     0.000000      5.000000      3.000000     5.000000      3.000000
# 50%     0.000000      6.000000     16.000000     6.000000      7.000000
# 75%     1.000000      6.000000     16.000000     6.000000     16.000000
# max     1.000000     13.000000     31.000000    13.000000     28.000000
#
#         weaptype3  weapsubtype3  weaptype4  weapsubtype4         nkill  \
# count  145.000000    126.000000   25.00000     22.000000  13830.000000
# mean     6.179310      6.595238    6.08000      8.772727      1.400362
# std      2.120236      6.243305    1.28841      7.016523      6.684258
# min      5.000000      2.000000    5.00000      2.000000      0.000000
# 25%      5.000000      3.000000    5.00000      2.000000      0.000000
# 50%      5.000000      3.000000    6.00000      7.000000      0.000000
# 75%      6.000000     10.000000    6.00000     16.000000      1.000000
# max     13.000000     23.000000    9.00000     23.000000    422.000000
#
#            nkillus     nkillter        nwound     nwoundus     nwoundte  \
# count  1369.000000  1458.000000  12406.000000  1339.000000  1321.000000
# mean      0.174580     0.353224      1.313074     0.373413     0.062074
# std       1.021435     2.524430      8.044576     2.368088     0.361929
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 25%       0.000000     0.000000      0.000000     0.000000     0.000000
# 50%       0.000000     0.000000      0.000000     0.000000     0.000000
# 75%       0.000000     0.000000      0.000000     0.000000     0.000000
# max      30.000000    85.000000    300.000000    50.000000     5.000000
#
#            property   propextent     propvalue     ishostkid     nhostkid  \
# count  16580.000000  7652.000000  3.803000e+03  16415.000000  1393.000000
# mean       0.617793     3.453999  1.858951e+05      0.084861   -12.320890
# std        0.838448     0.527484  1.703579e+06      0.278684   130.737644
# min       -9.000000     2.000000 -9.900000e+01      0.000000   -99.000000
# 25%        0.000000     3.000000  2.000000e+03      0.000000     1.000000
# 50%        1.000000     3.000000  7.000000e+03      0.000000     1.000000
# 75%        1.000000     4.000000  3.500000e+04      0.000000     2.000000
# max        1.000000     4.000000  5.000000e+07      1.000000  4000.000000
#
#         nhostkidus      nhours       ndays        ransom     ransomamt  \
# count  1393.000000  403.000000  289.000000  16316.000000  4.170000e+02
# mean      0.222541    7.361663   26.937716      0.025619  3.793429e+06
# std       4.098203   86.859659   67.460711      0.158001  4.932135e+07
# min     -99.000000  -99.000000    0.000000      0.000000  0.000000e+00
# 25%       0.000000    0.000000    0.000000      0.000000  0.000000e+00
# 50%       0.000000    0.000000    3.000000      0.000000  0.000000e+00
# 75%       0.000000    0.000000   23.000000      0.000000  4.150000e+05
# max      70.000000  999.000000  752.000000      1.000000  1.000000e+09
#
#        ransomamtus    ransompaid  ransompaidus  hostkidoutcome   nreleased  \
# count          1.0  8.800000e+01           1.0      638.000000  486.000000
# mean       20000.0  1.351280e+06           0.0        2.888715    8.341564
# std            NaN  4.853561e+06           NaN        1.280881   28.437426
# min        20000.0  0.000000e+00           0.0        2.000000  -99.000000
# 25%        20000.0  0.000000e+00           0.0        2.000000    1.000000
# 50%        20000.0  7.050000e+04           0.0        2.000000    1.000000
# 75%        20000.0  7.250000e+05           0.0        4.000000    2.000000
# max        20000.0  4.100000e+07           0.0        7.000000  215.000000
#
#             INT_LOG      INT_IDEO      INT_MISC       INT_ANY
# count  16580.000000  16580.000000  16580.000000  16580.000000
# mean      -3.738118     -3.693667      0.263450     -2.668034
# std        4.552678      4.601334      0.657961      4.561017
# min       -9.000000     -9.000000     -9.000000     -9.000000
# 25%       -9.000000     -9.000000      0.000000     -9.000000
# 50%        0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000

# %% [markdown]
# Analysing correlation between the data

# %%
df.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999874 -0.073447 -0.014073 -0.056763 -0.343004
# iyear      0.999874  1.000000 -0.083935 -0.014265 -0.056886 -0.342882
# imonth    -0.073447 -0.083935  1.000000  0.006187  0.015787  0.020288
# iday      -0.014073 -0.014265  0.006187  1.000000 -0.000184  0.029959
# extended  -0.056763 -0.056886  0.015787 -0.000184  1.000000 -0.068784
# ...             ...       ...       ...       ...       ...       ...
# nreleased  0.016154  0.016379 -0.020214 -0.019524  0.005261  0.073249
# INT_LOG   -0.094943 -0.094998  0.003717  0.015512  0.027543  0.209723
# INT_IDEO  -0.098444 -0.098503  0.004353  0.014178  0.035767  0.200065
# INT_MISC  -0.203957 -0.204274  0.045490  0.017197  0.032835  0.391481
# INT_ANY   -0.181606 -0.181694  0.012840  0.020345  0.032094  0.314172
#
#              region  latitude  longitude  specificity  vicinity     crit1  \
# eventid   -0.024912 -0.280651  -0.026098     0.114392  0.039217 -0.075487
# iyear     -0.024633 -0.280117  -0.025792     0.114723  0.039259 -0.076134
# imonth    -0.018343 -0.013284  -0.019874    -0.044679 -0.008862 -0.012977
# iday       0.009578  0.015753   0.011642    -0.013854 -0.001993  0.012238
# extended  -0.021478 -0.079776  -0.014184     0.033455 -0.006514 -0.008367
# ...             ...       ...        ...          ...       ...       ...
# nreleased  0.128473  0.145909   0.186215    -0.054100  0.001310  0.031725
# INT_LOG    0.137462  0.137264   0.110957    -0.005810  0.001226  0.121423
# INT_IDEO   0.138451  0.131992   0.111279    -0.007080 -0.000553  0.121182
# INT_MISC   0.201449  0.241090   0.159391    -0.059002 -0.012450  0.053535
# INT_ANY    0.242885  0.226777   0.210825    -0.048882 -0.005030  0.139094
#
#               crit2     crit3  doubtterr  alternative  multiple   success  \
# eventid    0.023108 -0.041910  -0.108685    -0.178724 -0.137166  0.043234
# iyear      0.023171 -0.041911  -0.108465    -0.178917 -0.137022  0.043195
# imonth    -0.007163  0.007225  -0.007183     0.030951 -0.002938  0.002698
# iday      -0.003585 -0.001570   0.007715    -0.026149  0.002566 -0.007058
# extended   0.014125  0.035656  -0.044256     0.012834 -0.009359  0.044607
# ...             ...       ...        ...          ...       ...       ...
# nreleased  0.011735  0.042894   0.021563    -0.198616  0.453986  0.033433
# INT_LOG   -0.039381 -0.025344   0.472513    -0.148552  0.080648 -0.005128
# INT_IDEO  -0.038426 -0.023534   0.475027    -0.149786  0.079121 -0.002672
# INT_MISC  -0.055503 -0.045666   0.067249    -0.027638  0.005450 -0.015407
# INT_ANY   -0.058288 -0.003860   0.375884    -0.110246  0.048638 -0.011591
#
#             suicide  attacktype1  attacktype2  attacktype3  targtype1  \
# eventid    0.007351    -0.039040     0.334462          1.0   0.074461
# iyear      0.007206    -0.038716     0.335359          1.0   0.074453
# imonth     0.013183    -0.031212    -0.107976          NaN  -0.013530
# iday      -0.000135    -0.049510     0.009568         -1.0   0.012570
# extended  -0.001122     0.170497     0.193723          NaN  -0.035175
# ...             ...          ...          ...          ...        ...
# nreleased       NaN    -0.410157     1.000000          NaN   0.041973
# INT_LOG    0.006377    -0.040585    -0.114942         -1.0  -0.054222
# INT_IDEO   0.007923    -0.039594    -0.123309         -1.0  -0.059834
# INT_MISC   0.008694    -0.043419    -0.106087          1.0  -0.007776
# INT_ANY    0.006246    -0.041101    -0.085836          1.0  -0.042930
#
#            targsubtype1   natlty1  targtype2  targsubtype2   natlty2  \
# eventid        0.073370 -0.365484  -0.060080     -0.063542 -0.483335
# iyear          0.073273 -0.364943  -0.060151     -0.063804 -0.483342
# imonth        -0.005513 -0.011959   0.012965      0.037124  0.005445
# iday           0.005756  0.018846  -0.139624     -0.131935 -0.150141
# extended      -0.026056 -0.011051   0.036046      0.080987 -0.130951
# ...                 ...       ...        ...           ...       ...
# nreleased      0.053538  0.165862   0.045364      0.154411  0.481802
# INT_LOG       -0.061487  0.145665   0.007207      0.055653  0.167357
# INT_IDEO      -0.065454  0.157488   0.007601      0.045246  0.156099
# INT_MISC       0.005166  0.389295   0.144041      0.086443  0.164732
# INT_ANY       -0.038267  0.251363   0.190175      0.157050  0.088257
#
#            targtype3  targsubtype3   natlty3  gsubname2  gname3  gsubname3  \
# eventid     0.446500      0.568352 -0.495705        NaN     NaN        NaN
# iyear       0.444073      0.566057 -0.496024        NaN     NaN        NaN
# imonth      0.164574      0.192012  0.066883        NaN     NaN        NaN
# iday        0.280568      0.361681 -0.397706        NaN     NaN        NaN
# extended    0.361693      0.155655 -0.369289        NaN     NaN        NaN
# ...              ...           ...       ...        ...     ...        ...
# nreleased  -0.324846     -0.642978 -0.417137        NaN     NaN        NaN
# INT_LOG    -0.248065     -0.368990  0.382804        NaN     NaN        NaN
# INT_IDEO   -0.287550     -0.371120  0.389287        NaN     NaN        NaN
# INT_MISC   -0.122556      0.021469  0.366238        NaN     NaN        NaN
# INT_ANY    -0.247170     -0.348416  0.341305        NaN     NaN        NaN
#
#            guncertain1  guncertain2  guncertain3  individual    nperps  \
# eventid       0.034648    -0.380930          NaN   -0.006596  0.542444
# iyear         0.034647    -0.383849          NaN   -0.006629  0.541891
# imonth       -0.005274     0.253984          NaN    0.002852  0.042641
# iday          0.000206    -0.498171          NaN   -0.006351 -0.033540
# extended     -0.010972          NaN          NaN    0.010270  0.077579
# ...                ...          ...          ...         ...       ...
# nreleased    -0.042844          NaN          NaN    0.005848  0.094889
# INT_LOG       0.095313     0.323553          NaN   -0.046577  0.169771
# INT_IDEO      0.095828     0.225891          NaN   -0.046827  0.173508
# INT_MISC     -0.031769    -0.249832          NaN   -0.012217  0.041657
# INT_ANY       0.064556     0.141081          NaN   -0.049944  0.199126
#
#            nperpcap   claimed  claimmode    claim2  claimmode2  claim3  \
# eventid    0.249183 -0.184513  -0.061576  0.769766   -0.062608     NaN
# iyear      0.251357 -0.181776  -0.049208  0.762493   -0.063758     NaN
# imonth     0.007358 -0.112659   0.047942  0.598597    0.144383     NaN
# iday      -0.020818 -0.021587   0.090910  0.067574   -0.360306     NaN
# extended   0.086529  0.038186   0.176113       NaN         NaN     NaN
# ...             ...       ...        ...       ...         ...     ...
# nreleased -0.559164  0.372537        NaN       NaN         NaN     NaN
# INT_LOG    0.116520 -0.021012   0.081994  0.395285   -0.349215     NaN
# INT_IDEO   0.121571 -0.022889   0.101942 -0.188982   -0.572637     NaN
# INT_MISC   0.019777  0.064903   0.137456  0.125000   -0.238559     NaN
# INT_ANY    0.123883 -0.029650   0.085187 -0.188982   -0.572637     NaN
#
#            claimmode3  claimmode3_txt  compclaim  weaptype1  weapsubtype1  \
# eventid           NaN             NaN   0.293754   0.025007     -0.188047
# iyear             NaN             NaN   0.328965   0.025301     -0.187751
# imonth            NaN             NaN   0.252422  -0.035070     -0.021642
# iday              NaN             NaN  -0.266160  -0.034877     -0.001037
# extended          NaN             NaN  -0.478091   0.277358     -0.070570
# ...               ...             ...        ...        ...           ...
# nreleased         NaN             NaN        NaN  -0.418127      0.228995
# INT_LOG           NaN             NaN   0.264575  -0.037749     -0.057538
# INT_IDEO          NaN             NaN   0.292922  -0.033434     -0.062810
# INT_MISC          NaN             NaN   0.039528  -0.035601      0.012576
# INT_ANY           NaN             NaN   0.169938  -0.033916     -0.027787
#
#            weaptype2  weapsubtype2  weaptype3  weapsubtype3  weaptype4  \
# eventid    -0.018846     -0.101701  -0.121588     -0.218798  -0.170135
# iyear      -0.018394     -0.101714  -0.122054     -0.217636  -0.163667
# imonth     -0.035615      0.009048   0.048731     -0.025546  -0.249529
# iday        0.035945     -0.031353   0.044531      0.113137   0.183118
# extended   -0.038370      0.014453  -0.011987     -0.037548   0.331703
# ...              ...           ...        ...           ...        ...
# nreleased  -0.152847     -0.038451  -0.101325      0.115488  -1.000000
# INT_LOG    -0.130257     -0.132853  -0.332321     -0.340964  -0.257748
# INT_IDEO   -0.136051     -0.141770  -0.321340     -0.335396  -0.271684
# INT_MISC   -0.045810      0.071604   0.055091     -0.112517  -0.027658
# INT_ANY    -0.138245     -0.072081  -0.322880     -0.331766  -0.253922
#
#            weapsubtype4     nkill   nkillus  nkillter    nwound  nwoundus  \
# eventid       -0.160105  0.093049  0.026076  0.107138  0.027250 -0.014381
# iyear         -0.153566  0.092982  0.025327  0.106695  0.027087 -0.014899
# imonth        -0.255062 -0.002974  0.067382  0.024572  0.012092  0.048788
# iday           0.053696 -0.008019 -0.016381  0.028137  0.006551 -0.019677
# extended       0.494845 -0.015005  0.155825  0.013283 -0.018858  0.109475
# ...                 ...       ...       ...       ...       ...       ...
# nreleased     -1.000000 -0.146456 -0.509075 -0.342457 -0.160739 -0.513926
# INT_LOG       -0.385362 -0.022773  0.087509  0.082223  0.020604  0.060368
# INT_IDEO      -0.402874 -0.022194  0.090278  0.081155  0.018786  0.061682
# INT_MISC      -0.257328 -0.039908  0.049894  0.016418  0.004022  0.000744
# INT_ANY       -0.396530 -0.047485  0.087768  0.080557  0.006715  0.040573
#
#            nwoundte  property  propextent  propvalue  ishostkid  nhostkid  \
# eventid    0.201477  0.125777    0.284859   0.027609   0.017736 -0.071053
# iyear      0.201003  0.125645    0.285257   0.027288   0.017600 -0.070755
# imonth     0.012008 -0.005736   -0.057241   0.025652   0.008928 -0.020951
# iday       0.029010  0.000675   -0.004324   0.005529  -0.012436 -0.012715
# extended   0.035942 -0.088666   -0.022970   0.011409   0.466109  0.083884
# ...             ...       ...         ...        ...        ...       ...
# nreleased -0.308724  0.157056    0.387679  -0.685899  -0.220653  0.880122
# INT_LOG    0.070385  0.000325    0.013090   0.059803   0.052265  0.021247
# INT_IDEO   0.069323 -0.001153    0.006410   0.061395   0.057522  0.024500
# INT_MISC   0.000363 -0.016348   -0.003219   0.000158  -0.013154  0.021267
# INT_ANY    0.063967  0.004175    0.007110   0.044743   0.036829  0.036125
#
#            nhostkidus    nhours     ndays    ransom  ransomamt  ransomamtus  \
# eventid      0.003028  0.106381 -0.099835 -0.034813   0.011431          NaN
# iyear        0.003014  0.106976 -0.100760 -0.034687   0.011813          NaN
# imonth       0.000761 -0.066146  0.091534 -0.009387  -0.035325          NaN
# iday         0.010449 -0.011692  0.044632 -0.006299   0.005622          NaN
# extended    -0.002420 -0.078690  0.232540  0.476789  -0.031796          NaN
# ...               ...       ...       ...       ...        ...          ...
# nreleased   -0.157369  0.287199 -0.112505 -0.041385   0.006199          NaN
# INT_LOG      0.026222 -0.024502 -0.032932  0.021373   0.038078          NaN
# INT_IDEO     0.028809 -0.020274 -0.020559  0.026594   0.034261          NaN
# INT_MISC     0.038752  0.014259  0.027884  0.004646  -0.016789          NaN
# INT_ANY      0.029800 -0.028968 -0.047814  0.019844   0.024469          NaN
#
#            ransompaid  ransompaidus  hostkidoutcome  nreleased   INT_LOG  \
# eventid     -0.125149           NaN        0.072241   0.016154 -0.094943
# iyear       -0.127657           NaN        0.071925   0.016379 -0.094998
# imonth       0.205668           NaN        0.026029  -0.020214  0.003717
# iday         0.010475           NaN        0.069097  -0.019524  0.015512
# extended    -0.134267           NaN       -0.098122   0.005261  0.027543
# ...               ...           ...             ...        ...       ...
# nreleased   -0.039907           NaN       -0.153808   1.000000 -0.004870
# INT_LOG     -0.048162           NaN       -0.091275  -0.004870  1.000000
# INT_IDEO    -0.043497           NaN       -0.102300  -0.005612  0.994732
# INT_MISC     0.020799           NaN       -0.017091   0.021751  0.126014
# INT_ANY      0.005692           NaN       -0.094841   0.021538  0.809657
#
#            INT_IDEO  INT_MISC   INT_ANY
# eventid   -0.098444 -0.203957 -0.181606
# iyear     -0.098503 -0.204274 -0.181694
# imonth     0.004353  0.045490  0.012840
# iday       0.014178  0.017197  0.020345
# extended   0.035767  0.032835  0.032094
# ...             ...       ...       ...
# nreleased -0.005612  0.021751  0.021538
# INT_LOG    0.994732  0.126014  0.809657
# INT_IDEO   1.000000  0.151753  0.811969
# INT_MISC   0.151753  1.000000  0.392578
# INT_ANY    0.811969  0.392578  1.000000
#
# [81 rows x 81 columns]

# %%
# Checking for missing data
df.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    16560
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       15876
# Length: 135, dtype: int64

# %% [markdown]
# no. of Deads or injured pepole in terror attack

# %%
df.nkillus.plot(kind = 'line', color = 'red', label = 'The Number of Total Confirmed Fatalities for US', linewidth = 2, alpha = 0.8, grid = True, 
                 linestyle = ':', figsize = (20,20), fontsize=15)
df.nwoundus.plot(color = "green", label = 'The Number of Confirmed Non-Fatal Injuries for US', linewidth = 2, alpha = 0.8, grid = True, 
                 linestyle = '-.', figsize = (20,20), fontsize=15)

plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('Database Index', fontsize=10)              # label = name of label
plt.ylabel('Number of Dead or Injuries', fontsize=15)

plt.title('Confirmed Fatalities & Non-Fatal Injuries for US')            #plot title
plt.show()

# %%
df.shape
# Out:
# (16581, 135)

# %%
# Let's see in which year, attacks happened most number of times

plt.rcParams['figure.figsize']=15,11
sns.countplot(y=df['iyear'], palette='inferno')

plt.xlabel('Number of attacks', fontsize=20, fontweight='bold')
plt.ylabel('Attack Year', fontsize=20, fontweight='bold')

plt.title('Trend of increase in Terror from 1970 to 2017', fontweight="bold", size=25)

plt.xticks(fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='iyear',hue='success',data=df)

plt.xlabel('Attack Year', fontsize=20, fontweight='bold')
plt.ylabel('Number of attacks', fontsize=20, fontweight='bold')

plt.title('Trend of increase in Terror from 1970 to 2017', fontweight="bold", size=25)

plt.xticks(rotation=60, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %%
#let's check which region is affected by terrorism in each year
@interact

def attack_year(year=list(df['iyear'].unique())):
    a = df[df['iyear']==year]
    return sns.countplot(y=a['region_txt'], palette='viridis')
# Out:
# interactive(children=(Dropdown(description='year', options=(1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 19…

# %%
#let's check which countries are affected more from each region
@interact
def country_name(region=list(df['region'].unique())):
    a=df[(df['region']==region)]
    a=pd.DataFrame(a['country'].value_counts())
    return a.style.background_gradient(cmap='plasma')
# Out:
# interactive(children=(Dropdown(description='region', options=(2, 1, 5, 8, 4, 3, 9, 11, 10, 12, 6), value=2), O…

# %%
#let's check which cities attacked most of the time from each country
@interact
def city_name(country=list(df['country'].unique())):
    a=df[df['country']==country]
    a=pd.DataFrame(a['city'].value_counts().head(10))
    return a.style.background_gradient(cmap='cool')
# Out:
# interactive(children=(Dropdown(description='country', options=(58, 130, 160, 78, 101, 217, 218, 98, 499, 65, 8…

# %%
plt.figure(figsize=(15,6))

sns.countplot(x='region_txt',data=df)

plt.xlabel('Region-wise', fontsize=20, fontweight='bold')
plt.ylabel('Number of attacks', fontsize=20, fontweight='bold')

plt.title('Total number of attacks Region-wise', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %%
plt.figure(figsize=(15,6))

sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)

plt.xlabel('Country', fontsize=20, fontweight='bold')
plt.ylabel('Total attack counts', fontsize=20, fontweight='bold')

plt.title('Total number of attacks Country-wise', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %%
plt.figure(figsize=(15,6))

sns.barplot(x=df['gname'].value_counts()[:20].index,y=df['gname'].value_counts()[:20].values)

plt.xlabel('Country', fontsize=20, fontweight='bold')
plt.ylabel('Total attack counts', fontsize=20, fontweight='bold')

plt.title('Total number of attacks group-wise', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %%
plt.figure(figsize=(15,6))

sns.barplot(x=df['targtype1_txt'].value_counts().index,y=df['targtype1_txt'].value_counts().values)

plt.xlabel('Target type', fontsize=20, fontweight='bold')
plt.ylabel('Total attack counts', fontsize=20, fontweight='bold')

plt.title('Total count of attack on differnt target type', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %%
df.plot(kind = 'scatter', x = 'nkill', y = 'nwound', alpha = 0.5, color = 'red', figsize = (20,20), fontsize=15)
plt.xlabel('Kill', fontsize=15)
plt.ylabel('Wound', fontsize=15)
plt.title('Kill - Wound Scatter Plot')
plt.show()

# %% [markdown]
# #**Conclusion**
#
# ---
#
#
#
# Iraq ranked first on the global terrorism for their
#
# terrorist activity followed by Pakistan, Afganistan, India, and so on
#
# Most targeted areas are private citizens and property, military, police, and so on
#
# Global terror attack deaths rose sharply starting year 2011
#
# In conclusion with the ranking,
# Iraq suffered from most terrorist attacks in 2014, with the most deaths in that year
